# %% [markdown]
# # <font color='deeppink'>LINEAR REGRESSION</font>
#
# ## <b>1.0 General explanation about <font color='deeppink'>Linear Regression</font> </b>
#
# <font size =3 >Regression is the using of the relationship between variables to find best fit line or best equation. Best fit line is used to get the most accurate data which from there, we can make the best prediction. Linear regression is used for continuous data, or two correlated variables.

# %% [markdown]
# ![alt text](https://cdn-images-1.medium.com/max/1200/1*xz_haBuJRSI2DaveNk-3gw.gif)
# $$ Y = a_1X_1 + b (randomError) $$

# %% [markdown]
# ## <b>1.1 Method used to calculate <font color='deeppink'>Linear Regression</font> line.</b>

# %% [markdown]
# # $$ y = A + Bx $$
#
# <font size =4>Method used: </font><font size =4 color='orangered'><b>LEAST SQUARE METHOD</b></font><br><br>
#
# - <font size=4> A method to estimate the true value of some quantity <b>based on a consideration of errors </b>in observations or measurements.</font><br><br>
#
# - <font size=4> It provides the <b>overall rationale placement of the line of the best fit</b> among the data points being studied. </font><br><br>
#
# - <font size =4>AIM:<b> To calculate the values B (slope) and A (y-intercept) in the equation of a line.</b></font>

# %% [markdown]
# ##  1.2 <font color='orangered'>Least Square Method </font>Explanation <br>
# - <font size =4> It finds <b> all possible line equations </b>for a given set of data points and select the one <b>which has the least squared sum of errors (residual).</b></font><br><br>
#
# - <font size =4><b>ERRORS :</b> the <b>difference</b> between the an observed value <font color='red'><b>(actual)</b></font> and the fitted value provided by a model <font color='red'><b>(predicted)</b></font></font><br><br>
#
# - <font size =4> So our equation will produce <b>the value of y with the least value of errors </b></font> <br><br>
#
# ![alt_text](https://muthu.co/wp-content/uploads/2018/06/Snip20180616_19.png)

# %% [markdown]
# ## <b>2.0 The manual steps to find the <font color="orangered">Linear Regression:</font>

# %% [markdown]
# <font size =4 >1. You have to build the <b>new equation </b>which consists of the least error values </font>
#
# <font size =4 >2. So, find the <b>new slope (B)</b></font>
#
# ## $$ B = \frac {n\sum xy - \sum x \sum y} { n\sum x^2 - (\sum x)^2} $$
#
# <font size =4 >3. Then, calculate the <b>y-intercept </b></font>
#
# ## $$ A = \frac {n\sum y - B\sum x} { n} $$
#
# <font size =4>So, in order to calculate the values of B and A, you first need :</font>
# ## $x^2$, $y^2$, $xy$
# ## $\sum x$, $\sum y$, $\sum x^2$, $\sum y^2$, $\sum xy$<br>

# %% [markdown]
# ## 2.1 Further explanation with video

# %%
# %%HTML
# <iframe width="900" height="500" src="https://www.youtube.com/embed/zPG4NjIkCjc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="900" height="500" src="https://www.youtube.com/embed/zPG4NjIkCjc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 3.0 Finding Linear Regression equation <font color="deeppink">using Python.</font>

# %% [markdown]
# ## <font color='blue'>STEP 1:</font>
#
# <font size =4> Store your data inside a table, which consists of column $x$ and $y$. Then, add 3 more columns inside the table labelled $xy$, $x^2$, and $y^2$. Note that $xy$ is the product of $x$ and $y$, $x^2$ is the square of $x$, and $y^2$ is the square of $y$.</font><br>
#
# <font size =4> As we are using python to do the calculation, you can use list to store the values of x and y. It will be easier and faster to handle the data. </font>

# %%
import numpy as np
import matplotlib.pyplot as plt

x= np.arange(0,10,0.1)   # generate random value of x
y= (x*2) + (np.random.normal(0,1,len(x))*3)   # generate random value of x

plt.xlabel('X')
plt.ylabel('Y')
plt.scatter(x,y)

## Step 1
xy=[]
x2=[]
y2=[]   # create an empty list for each of the new column

for m in range(len(x)):
    ab = x[m] * y[m]   # calculate x*y
    xy.append(ab)      # append each value of x*y into the list
# print("xy: "+ str(xy))

for i in x:
    a= i**2        # calculate x power of 2
    x2.append(a)   # append each value of x^2 into the list
# print("x2: "+ str(x2))

for j in y:
    b= j**2        # calculate y power of 2
    y2.append(b)   # append each value of y^2 into the list
# print("y2: "+ str(y2))

# %% [markdown]
# ## <font color='blue'>STEP 2:</font>
# <font size =4> Now add a new row to the bottom of your table. This row should store the total sum of each of column $x$, $y$, $xy$, $x^2$, and $y^2$. Use for loop to get the sum of each column. </font>

# %%
## Step 2

nX=0
nY=0
nXY=0
nX2=0
nY2=0   # initialize the sum of each column as 0

for i in x:
    nX += i   # calculate sum of x
print("Sum of x: "+str(nX))   


for j in y:
    nY += j   # calculate sum of y
print("Sum of y: "+str(nY))


for k in xy:
    nXY += k   # calculate sum of xy
print("Sum of xy: "+str(nXY))


for m in x2:
    nX2 += m   # calculate sum of x2
print("Sum of x2: "+str(nX2))


for n in y2:   
    nY2 += n   # calculate sum of y2
print("Sum of y2: "+str(nY2))
# Out:
# Sum of x: 495.0
# Sum of y: 1038.3438771091264
# Sum of xy: 6970.038340745252
# Sum of x2: 3283.5000000000005
# Sum of y2: 15837.179789842347

# %% [markdown]
# ## <font color='blue'>STEP 3:</font>
#
# <font size =4>Using the following formula, calculate the value of $B$ (slope). Note that $n$ is the sample size (number of item) of the table. Make sure you translate the formula correctly for the calculation. </font>
#
# ## $$ B = \frac {n\sum xy - \sum x \sum y} { n\sum x^2 - (\sum x)^2} $$
#
# <font size =4>Then, calculate the value of $A$ (intercept) using the formula which consists of $B$ that we calculated before. </font>
#
# ## $$ A = \frac {n\sum y - B\sum x} { n} $$

# %%
## Step 3
n= len(x)

B= 0   # initialize B and A to 0
A= 0

B = ((n*nXY) - (nX*nY)) / (n*nX2 - (nX**2))
A = ((nY) - B*(nX)) / n  # Translate the formula into calculation for A and B

print("B (slope)    : "+str(B))
print("A (intercept): "+str(A))
# Out:
# B (slope)    : 2.1965030291690066
# A (intercept): -0.4892512232953186

# %% [markdown]
# ## <font color='blue'>STEP 4:</font>
# <font size =4>Insert the values into the equation: </font>
# ## $y = A + Bx$
# <font size =4> You can use for loop to generate the new $y$, for each value of $x$ to form the linear regression line. Store the value of new $y$ inside a list as we want to use it later on. </font>

# %%
## Step 4

Y= []
for i in range(n):
    y0=  A + (B*x[i]) 
#     y0= A + B*x[i]
    Y.append(y0)
# print(Y)

# %% [markdown]
# ## <font color='blue'>STEP 5:</font>
# ## Use 'plot(x, y)' function from matplotlib to form the linear regression line.

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.scatter(x,y)
plt.plot(x,Y, c="red")

# %% [markdown]
# ## 3.1 <font color="deeppink">Using Python libraries</font> to Construct Linear Regression Equation and Line

# %% [markdown]
# ## <font color='orchid'>STEP 1:</font>
# <font size =4> Import necessary function and libraries which is <b>numpy, matplotlib, and LinearRegression from sklearn.linear_model</b> </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## <font color='orchid'>STEP 2:</font>
#
# <font size =4>Store your data inside a list. In this case, we generate formula data by using <b>arange()</b> function from numpy
# </font>

# %%
x= np.arange(0,10,0.1)
# generate data of x from 1-10 with difference of 0.1 between each data

y= 1 + (x*2) + (np.random.normal(0,1,len(x))*3)
# generate y based on x value using y=A + Bx + random noise (to make more realistic data)

# %% [markdown]
# ## <font color='orchid'>STEP 3:</font>
#
# <font size =4> Plot the scattered (random) data by using <b>scatter()</b> function from matplotlib</font>

# %%
plt.xlabel('X')
plt.ylabel('Y')   # label the axis

plt.scatter(x,y)
# plot the points of each (x,y)

# %% [markdown]
# ## <font color='orchid'>STEP 4:</font>
# <font size =4> Transform data into column vector by inserting new axis by using <b>newaxis</b> function from numpy.</font>

# %%
x= x[:, np.newaxis]
y= y[:, np.newaxis]
# transform data into column vector by inserting new axis

# %% [markdown]
# ## <font color='orchid'>STEP 5:</font>
# <font size =4> Introduce <b>LinearRegression</b> function to a variable </font>

# %%
model= LinearRegression(fit_intercept= True)   # if false, the y intercept will always be 1
# import linearRegression module from sklearn

# %% [markdown]
# ## <font color='orchid'>STEP 6:</font>
# <font size =4>Use <b>fit(x,y)</b> function to fit the line into scattered data. </font>

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## <font color='orchid'>STEP 7:</font>
# <font size =4> Use <b>predict(x)</b> function to find the value of estimated y based on x, then plot the line using <b>plot()</b> function from matplotlib. </font>

# %%
plt.xlabel('X')
plt.ylabel('Y')   # label the axis

plt.scatter(x,y)
# plot the points of each (x,y)
y_pred = model.predict(x)
plt.plot(x, y_pred, color='r')

# %% [markdown]
# ## 4.0 <font color="deeppink">Questions</font> about Linear Regression
# ## <font color='palevioletred'>Part 1: Linear Regression with normal calculation.</font>

# %% [markdown]
# <font size =4> Table 1 below shows the amount hours spent for study and the mark achieved by students based on their hours of studying.</font>

# %%
import pandas as pd
import numpy as np

a= [2,3,4,4.5,5,6,6.5,8,8.5,9,9.5,10]
b= [44,50,60,54,65,73,81,89,84,90,103,120]

df = pd.DataFrame(a, columns = ['Number of hours (x)']); df['Marks achieved in examination (y)'] = b
df.style.set_properties(**{'text-align':'center'})
# Out:
# <style  type="text/css" >
#     #T_974d1630_91a5_11e9_8b94_80a5898a2454row0_col0 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row0_col1 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row1_col0 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row1_col1 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row2_col0 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row2_col1 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row3_col0 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row3_col1 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row4_col0 {
#             text-align:  center;
#         }    #T_974d1630_91a5_11e9_8b94_80a5898a2454row4_col1 {
# ...

# %% [markdown]
# ## Question 1:
# <font size =4> From the following table, add 3 more new columns into the table which consists of $x^2$, $y^2$, and $xy$. Calculate the value of each row of data. </font>
# ## <font color ="red">Hint: </font>
# <font size =4> Use array and for loop for faster calculation of data. </font>

# %%
## Task 1

x= [2,3,4,4.5,5,6,6.5,8,8.5,9,9.5,10]
y= [44,50,60,54,65,73,81,89,84,90,103,120]

xy=[]
x2=[]
y2=[]   # create an empty list for each of the new column

for m in range(len(x)):
    ab = x[m] * y[m]   # calculate x*y
    xy.append(ab)      # append each value of x*y into the list
print("xy: "+ str(xy))

for i in x:
    a= i**2        # calculate x power of 2
    x2.append(a)   # append each value of x^2 into the list
print("x2: "+ str(x2))

for j in y:
    b= j**2        # calculate y power of 2
    y2.append(b)   # append each value of y^2 into the list
print("y2: "+ str(y2))
# Out:
# xy: [88, 150, 240, 243.0, 325, 438, 526.5, 712, 714.0, 810, 978.5, 1200]
# x2: [4, 9, 16, 20.25, 25, 36, 42.25, 64, 72.25, 81, 90.25, 100]
# y2: [1936, 2500, 3600, 2916, 4225, 5329, 6561, 7921, 7056, 8100, 10609, 14400]

# %% [markdown]
# ## Question 2:
# <font size =4 >Add a new row at the bottom part of the table. Calculate the total sum of each of the column, $\sum x$, $\sum y$, $\sum xy$, $\sum x^2$, and $\sum y^2$. </font>

# %%
## Task 2

nX=0
nY=0
nXY=0
nX2=0
nY2=0   # initialize the sum of each column as 0

for i in x:
    nX += i   # calculate sum of x
print("Sum of x: "+str(nX))   


for j in y:
    nY += j   # calculate sum of y
print("Sum of y: "+str(nY))


for k in xy:
    nXY += k   # calculate sum of xy
print("Sum of xy: "+str(nXY))


for m in x2:
    nX2 += m   # calculate sum of x2
print("Sum of x2: "+str(nX2))


for n in y2:   
    nY2 += n   # calculate sum of y2
print("Sum of y2: "+str(nY2))
# Out:
# Sum of x: 76.0
# Sum of y: 913
# Sum of xy: 6425.0
# Sum of x2: 560.0
# Sum of y2: 75153

# %% [markdown]
# ## Question 3:
#
# ## $$ B = \frac {n\sum xy - \sum x \sum y} { n\sum x^2 - (\sum x)^2} $$
#
# ## $$ A = \frac {n\sum y - B\sum x} { n} $$
#
# <font size =4>Using the following formula, calculate the value of gradient (B). Then using B value, find the value of $y$-intercept (A). Note that $n$ is the sample size (number of item) of the table. </font>

# %%
## Task 3

n= len(x)

A= 0
B= 0   # initialize A and B to 0

A = ((nY*nX2) - (nX*nXY)) / (n*nX2 - (nX**2))  # Translate the formula into calculation for A and B
B = ((n*nXY) - (nX*nY)) / (n*nX2 - (nX**2))

print(A)
print(B)
# Out:
# 24.343220338983052
# 8.169491525423728

# %% [markdown]
# ## Question 4:
#
# <font size =4> Insert the value of A and B into equation: $y = A + Bx$. Calculate the value of $y$ for each $x$. </font>
#
# ## <font color ="red">Hint: </font>
# <font size =4> Use array and for loop to calculate the value of Y depending on X value. </font>

# %%
## Task 4

Y= []
for i in range(n):
    y0= A + B*x[i]
    Y.append(y0)
print(Y)
# Out:
# [40.682203389830505, 48.851694915254235, 57.021186440677965, 61.10593220338983, 65.1906779661017, 73.36016949152543, 77.44491525423729, 89.69915254237287, 93.78389830508473, 97.8686440677966, 101.95338983050848, 106.03813559322035]

# %% [markdown]
# ## Question 5:
# <font size =4> You are finally there! Now you can draw your linear regression line. Congratulations and happy drawing. </font>

# %%
## Task 5

import numpy as np
import matplotlib.pyplot as plt

# print(len(y))

plt.xlabel("x")
plt.ylabel("y")
plt.scatter(x,y)
# plt.scatter(x,Y, c="green")
plt.plot(x,Y, c="red")
plt.show()

# %% [markdown]
# ## Question 6:
# <font size =4> A student studied diligently for 11 hours and sit for an examination. What is likely to be his/her mark achieved? </font>
# ## <font color ="red">Hint: </font>
# <font size =4> You have to use the equation of the regression line and find the value of $y$ based on a certain value of $x$. </font>

# %%
## Task 6
y0= A + B*11
print("Mark achieved: "+ str(y0))
# Out:
# Mark achieved: 114.20762711864407

# %% [markdown]
# ## Question 7:
# <font size =4> A student has achieved a mark of 95 for his examination. Can you find what is approximately the hours taken by him to study for the examination? </font>
# ## <font color ="red">Hint: </font>
# <font size =4> You have to modify the equation of the regression line to find a specific value of $x$ based on a certain value of $y$. </font>

# %%
## Task 7:
# 95= A + B*x 
# B*x = 95 - A
x= (95 - A) / B   # conversion of equation so that we can find the value of x

print("Hours studied: "+str(x))
# Out:
# Hours studied: 8.648858921161825

# %% [markdown]
# # <font color='palevioletred'>Part 2: Linear Regression with Python Libraries</font>

# %% [markdown]
# ## Question 8:
# <font size =4> From the same Table 1, we want to recreate the linear regression line, but using Python Libraries. Firstly, import certain Python libraries to be used for these questions. The libraries are <b>numpy, matplotlib.pyplot, and LinearRegression from sklearn.linear_model</b> </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Task1
import numpy as np

x= [2,3,4,4.5,5,6,6.5,8,8.5,9,9.5,10]
y= [44,50,60,54,65,73,81,89,84,90,103,120]   # put the data into a list for easier to handle the data

x= np.array(x)   # intialize type as array
y= np.array(y)

# %% [markdown]
# ## Question 9:
# <font size =4 >Store the data x and y into lists. One for x, and another one for y. Initialize them as array by using array() function from numpy. Then, plot the following data into a graph. </font>
# ## <font color ="red">Hint: </font>
# <font size =4 >Use scatter() and show() function for the plotting.</font>

# %%
x= [2,3,4,4.5,5,6,6.5,8,8.5,9,9.5,10]
y= [44,50,60,54,65,73,81,89,84,90,103,120]   # store the data into a list

x= np.array(x)   # intialize type as array so that it is compatible with other functions 
y= np.array(y)

import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Question 10:
# <font size =4 >Construct a best-fit line along the scattered data so that we can predict the mark achieved by students according to the amount of hours spent on studying. </font>
# ## <font color ="red"> Hint: </font>
# <font size =4> <b>Import library:</b> numpy, sklearn.linear_model, LinearRegression </font><br>
# <font size =4 ><b>Use function:</b> newaxis, fit(), predict() </font>

# %%
from sklearn.linear_model import LinearRegression

plt.scatter(x,y)   # plot the scattered data

x1= x[:, np.newaxis] 
y1= y[:, np.newaxis]   # transform data into column vector by inserting new axis

model= LinearRegression(fit_intercept= True)   # import linearRegression module from sklearn

model.fit(x1,y1)
y_pred = model.predict(x1)

plt.plot(x1, y_pred, color='r')
plt.xlabel("X")   # label x-axis
plt.ylabel("Y")   # label y-axis
plt.title("Linear Regression")   # label title
plt.show()

# %% [markdown]
# # project: check this link to analyse diabet dataset with linear regression model.

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html?fbclid=IwAR2pnt3b6I3LV-82Qv7-0c0GcVLxpUka4m-HCnOUdiLCMGAnylWfH4kd34A#sphx-glr-auto-examples-linear-model-plot-ols-py
